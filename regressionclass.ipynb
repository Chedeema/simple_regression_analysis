# %% [markdown]
# # Regression Analysis

# %% [markdown]
# - Simple Linear Regression: $$Y = \beta_0 + \beta_1X + \epsilon$$
# - Multiple Linear Regression: $$Y = \beta_0 + \beta_1X_1 + \beta_2X_2 + \dots + \beta_nX_n + \epsilon$$

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
data = pd.read_csv('marketing_company_data.csv')
data
# Out:
#      Campaign ID  Budget (USD)  Clicks  Impressions  Conversions Region  \
# 0              1          8270    1943        92747          386  South
# 1              2          1860     588        63752          460  South
# 2              3          6390    3076        57573          347   East
# 3              4          6191    2059        60101          189   East
# 4              5          6734    2485        27646          190   East
# ..           ...           ...     ...          ...          ...    ...
# 195          196          7546    4648        14116          251  North
# 196          197          2986    3059        26470          225  North
# 197          198          9338    2365        43344          293  South
# 198          199          3911    2579        43918          305  North
# 199          200          2734    4746        53224           97  South
#
#            Date
# 0    2023-01-01
# 1    2023-01-02
# 2    2023-01-03
# 3    2023-01-04
# ...

# %%
#Define your dependent and independent variables
X = data['Budget (USD)']
Y = data['Conversions']

# %%
#Add a constant to the independent variable
X = sm.add_constant(X)

#fit the regression model
model = sm.OLS(Y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            Conversions   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7331
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):              0.393
# Time:                        11:33:37   Log-Likelihood:                -1270.3
# No. Observations:                 200   AIC:                             2545.
# Df Residuals:                     198   BIC:                             2551.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# - Intercept: $\beta_0$
# - slope: $\beta_1$
#
# - Intercept is the predicted value of conversion when budget is 0
# - Slope is the change in conversions for a non-unit increase in budget
# - an r square close to 1 indicates a strong relationship between budget and conversion
# - p-value is less than 0.05 it suggest that there is a strong relationship between budget and conversions, therefore a good statistical predictor

# %% [markdown]
# $Y = 231.5751 + 0.0033 * X$

# %%
#Extract independent and dependent variable
X = data['Budget (USD)']
Y= data['Conversions']

#Coefficients from the regression model
beta_0 = 231.5751 #(Intercept)
beta_1 = 0.0033  #(Slope)

#Generate the trendline using regression euqtion
y_pred = beta_0 + beta_1*X

#Plot the scatter chart
sns.scatterplot(x = X, y = Y)
plt.title('Budget Vs. Conversion')

# Add a trendline
plt.plot(X, y_pred, color = 'red', label = 'Trendline')

plt.legend()

plt.xlabel('Budget (USD)')
plt.ylabel('Conversions')
plt.show()
